# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fernando Castro**
#
# Business Analyst

# %% [markdown]
# *I am interested in Data Science because the world has become increasingly data dependent. The largest firms in the world, which have shaped our culture, have proven that data is what drives decisions and I want to be a part of this Data Revolution.*

# %% [markdown]
# ### The following code calulates 9 multiplied by 9

# %%
9*9
# Out:
# 81

# %% [markdown]
# ***
# ### Bulleted List
# - First Bullet Point
# - Second Bullet Point
# - Third Bullet Point
# - Fourth Bullet Point
#
# ### Hyperlink
# <a href="https://www.ibm.com/docs/en/db2-event-store/2.0.0?topic=notebooks-markdown-jupyter-cheatsheet">Markdown for Jupyter notebooks cheatsheet</a>
#
# ### IMB Logo From Dowloaded Image
# ![IBM.png](attachment:38d27b8d-685a-4328-931f-a5a8d7a30eef.png)
#
# ### Blocked Quote
# > This is an example of a blocked quote
